# %% [markdown]
# <a href="https://colab.research.google.com/github/fortunato23/Desafio/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Risco de Crédito Imobiliario
#
# #Tema: Grau de endividamento no Crédito Imobiliário
#
# *Foi* utilizado a base de dados do Risco de crédito no Kaggle ( https://www.kaggle.com/datasets/caesarlupum/risco-de-credito)![Risco-de-Crédito-finanças-contas.png](data:image/png;base64,...)
#
# #Introdução
#
# O risco de crédito é definido como a probabilidade de um devedor não honrar seus compromissos dentro do prazo acordado. Podemos citar como produtos dentro do risco de crédito os empréstimos pessoais e imobiliario, cartões de crédito e compras parceladas de qualquer natureza.
#
# #Objetivos Proposto:
#
# Média da variavel de inadiplentes de 30 até 59 dias;
# Média da Variavel de inadiplentes de 60 até 89 dias; e
# Média da variavel idade no Crédito Imobiliário.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn_pandas

# %%
Risco = pd.read_csv('Risco.csv')

# %%
Risco.head()
# Out:
#    inadimplente  util_linhas_inseguras  idade  vezes_passou_de_30_59_dias  \
# 0             1               0.766127     45                           2
# 1             0               0.957151     40                           0
# 2             0               0.658180     38                           1
# 3             0               0.233810     30                           0
# 4             0               0.907239     49                           1
#
#    razao_debito  salario_mensal  numero_linhas_crdto_aberto  \
# 0      0.802982          9120.0                          13
# 1      0.121876          2600.0                           4
# 2      0.085113          3042.0                           2
# 3      0.036050          3300.0                           5
# 4      0.024926         63588.0                           7
#
#    numero_vezes_passou_90_dias  numero_emprestimos_imobiliarios  \
# 0                            0                                6
# ...

# %%
Risco.tail()
# Out:
#         inadimplente  util_linhas_inseguras  idade  \
# 109995             0               0.137396     59
# 109996             0               0.276964     46
# 109997             0               0.181257     43
# 109998             0               0.037699     86
# 109999             0               1.000000     57
#
#         vezes_passou_de_30_59_dias  razao_debito  salario_mensal  \
# 109995                           1      0.448912          9600.0
# 109996                           0      0.491288         12224.0
# 109997                           0      0.382635         12000.0
# 109998                           0      0.248107          7000.0
# 109999                           0      0.002352          3825.0
#
#         numero_linhas_crdto_aberto  numero_vezes_passou_90_dias  \
# 109995                          10                            0
# 109996                          19                            0
# 109997                          13                            0
# ...

# %%
Risco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110000 entries, 0 to 109999
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   inadimplente                           110000 non-null  int64
#  1   util_linhas_inseguras                  110000 non-null  float64
#  2   idade                                  110000 non-null  int64
#  3   vezes_passou_de_30_59_dias             110000 non-null  int64
#  4   razao_debito                           110000 non-null  float64
#  5   salario_mensal                         88237 non-null   float64
#  6   numero_linhas_crdto_aberto             110000 non-null  int64
#  7   numero_vezes_passou_90_dias            110000 non-null  int64
#  8   numero_emprestimos_imobiliarios        110000 non-null  int64
#  9   numero_de_vezes_que_passou_60_89_dias  110000 non-null  int64
# ...

# %%
sum(Risco.duplicated())
# Out:
# 363

# %% [markdown]
# Aqui foi detectado 363 duplicidade de informação. Sendo necessario uma limpeza.

# %%
Risco = Risco.drop_duplicates()

# %%
print(Risco)
# Out:
#         inadimplente  util_linhas_inseguras  idade  \
# 0                  1               0.766127     45
# 1                  0               0.957151     40
# 2                  0               0.658180     38
# 3                  0               0.233810     30
# 4                  0               0.907239     49
# ...              ...                    ...    ...
# 109995             0               0.137396     59
# 109996             0               0.276964     46
# 109997             0               0.181257     43
# 109998             0               0.037699     86
# 109999             0               1.000000     57
#
#         vezes_passou_de_30_59_dias  razao_debito  salario_mensal  \
# 0                                2      0.802982          9120.0
# 1                                0      0.121876          2600.0
# 2                                1      0.085113          3042.0
# 3                                0      0.036050          3300.0
# ...

# %%
util_linhas_inseguras = Risco.drop

# %%
numero_de_dependentes = Risco.drop

# %%
Risco['vezes_passou_de_30_59_dias'].describe()
# Out:
# count    109637.000000
# mean          0.400431
# std           3.951084
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          98.000000
# Name: vezes_passou_de_30_59_dias, dtype: float64

# %% [markdown]
# Aqui é possível notar depois de efetuado calculo que a média de pessoas que passaram de 30 ate 59 dias inadiplentes é de 40%.

# %%
Risco['numero_de_vezes_que_passou_60_89_dias'].mean()
# Out:
# 0.21967036675574853

# %% [markdown]
#  Para o número de vezes que a inadiplencia passou de 60 até 89 dias, temos uma média de 22,00%.

# %%
vezes_passou_de_30_59_dias = np.random.randint(1,100,10)
numero_de_vezes_que_passou_60_89_dias = np.random.randint(1,100,10)
x = np.linspace(1,2,10)
plt.plot(x,vezes_passou_de_30_59_dias)
plt.plot(x,numero_de_vezes_que_passou_60_89_dias)
plt.show()

# %% [markdown]
# Neste grafico temos um comparativo entre as vezes qe passou de 30 ate 59 dias (cor azul) x 60 a 89 dias (cor laranja).

# %%
Risco['numero_emprestimos_imobiliarios'].sum()
# Out:
# 112188

# %% [markdown]
# Os emprestimos imobliarios contabilizam 112.188 contratos.

# %%
Risco['numero_linhas_crdto_aberto'].sum()
# Out:
# 928478

# %%
x = ('numero_linhas_crdto_aberto') 
plt.plot(x)
plt.show()

# %% [markdown]
# Temos um valor de 928.478 de linhas de crédito aberto somando-se inadiplentes de 30 ate 59 e 60 até 89 dias.

# %%
Risco.hist(column='idade', bins=100)
plt.show()

# %% [markdown]
# Ao calcular a média de idade dos contratantes de emprestimos imobiliarios percebe-se que os inadiplentes tem uma média de 52 anos. O histograma reforça a informação.

# %%
Risco['salario_mensal'].describe()
# Out:
# count    8.817700e+04
# mean     6.641456e+03
# std      1.338760e+04
# min      0.000000e+00
# 25%      3.400000e+03
# 50%      5.400000e+03
# 75%      8.233000e+03
# max      3.008750e+06
# Name: salario_mensal, dtype: float64

# %% [markdown]
# Percebe-se que 75% dos inadiplentes tem em média salarial R$ 8.233,00.

# %% [markdown]
# #Considerações Finais
#
# Através do estudo quando feito os calculo nota-se que 40% dos contratos foram atrasados dentro de 30 a 59 dias. Enquanto 21% atrasaram acima de 60 a 84 dias dos seus contratos. Constatando que os contratos pago em dias ficaram em 39% dos casos.
#
# Observa-se através dos levantamentos feitos que a média de idade da inadiplencia fica em torno de 52,26% e a quantidade de contratos de emprestimos aberto passar dos  928.478. Já os emprestimos imobiliarios ficaram na casa de 112.188 dos contratos representando 12% dos emprestimos inadiplentes.
#
# #Limitações
#
# Foi possível verifica atraves dos dados analisados, a ocorrencia de algumas limitações pela ausencia de informações.
#
# Foram encontrado 363 duplicidades de dados, que foram retirados para se obter melhores resultados.
#
# Utilid. de Linhas Seguras faltava dados e por isso não foi incluido no estudo.

# %% [markdown]
# https://www.youtube.com/watch?v=t1d0gZ99G_Y
